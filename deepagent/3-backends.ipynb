# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["MISTRAL_API_KEY"]=os.getenv("MISTRAL_API_KEY")
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
os.environ["TAVILY_API_KEY"]=os.getenv("TAVILY_API_KEY")

# %% [markdown]
# ### STATEBACKEND

# %%
import os
from deepagents import create_deep_agent
from deepagents.backends import StateBackend

# %%
agent = create_deep_agent(model="mistral-small-latest")
agent2 = create_deep_agent(
    model="mistral-small-latest",
    backend=StateBackend(),
)

# %%
result = agent2.invoke({
    "messages":[{
        "role": "user",
        "content": (
            "Create a file at /notes/todo.txt with exactly this content: \n"
            "1. Record video \n 2. Edit video \n 3. Upload video\n"
            "Then tell me you have done it."
        )
    }]
})

print("\n --- Agent reply---------------------------")
print(result["messages"][-1].content)
# Out:
#  --- Agent reply---------------------------
# I have created the file `/notes/todo.txt` with the specified content.

# %%
result
# Out:
# {'messages': [HumanMessage(content='Create a file at /notes/todo.txt with exactly this content: \n1. Record video \n 2. Edit video \n 3. Upload video\nThen tell me you have done it.', additional_kwargs={}, response_metadata={}, id='a4e0a821-b1d7-43dd-a1c8-e22b122a6346'),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'P260bgpcP', 'type': 'function', 'function': {'name': 'write_file', 'arguments': '{"file_path": "/notes/todo.txt", "content": "1. Record video \\n2. Edit video \\n3. Upload video"}'}, 'index': 0}]}, response_metadata={'token_usage': {'prompt_tokens': 2610, 'total_tokens': 2646, 'completion_tokens': 36, 'prompt_tokens_details': {'cached_tokens': 0}, 'service_tier': 'standard'}, 'model_name': 'mistral-small-latest', 'model': 'mistral-small-latest', 'finish_reason': 'tool_calls', 'model_provider': 'mistralai'}, id='lc_run--01a060f4-8b62-7092-8c4a-967d4bfdcd90-0', tool_calls=[{'name': 'write_file', 'args': {'file_path': '/notes/todo.txt', 'content': '1. Record video \n2. Edit video \n3. Upload video'}, 'id': 'P260bgpcP', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 2610, 'output_tokens': 36, 'total_tokens': 2646}),
#   ToolMessage(content='Updated file /notes/todo.txt', name='write_file', id='ef22e150-9ea4-4c4c-aaf8-633a2bb8ba07', tool_call_id='P260bgpcP'),
#   AIMessage(content='I have created the file `/notes/todo.txt` with the specified content.', additional_kwargs={}, response_metadata={'token_usage': {'prompt_tokens': 2655, 'total_tokens': 2672, 'completion_tokens': 17, 'prompt_tokens_details': {'cached_tokens': 0}, 'service_tier': 'standard'}, 'model_name': 'mistral-small-latest', 'model': 'mistral-small-latest', 'finish_reason': 'stop', 'model_provider': 'mistralai'}, id='lc_run--01a060f4-8f29-72c1-93e7-e66d4616e359-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2655, 'output_tokens': 17, 'total_tokens': 2672})],
#  'files': {'/notes/todo.txt': {'content': '1. Record video \n2. Edit video \n3. Upload video',
#    'encoding': 'utf-8',
#    'created_at': '2026-09-02T07:10:35.302331+00:00',
#    'modified_at': '2026-09-02T07:10:35.302331+00:00'}}}

# %%
print("\n--- Backend check----------------------------------------")
files = result.get("files", {})

if files:
    print(f" stateBackend is working - {len(files)} file(s) in state:")
    for path, content in files.items():
        print(f"\n {path} \n {'-'*40} \n {content}")
else:
    print(" No files found in state. Either the agent didn't write a file,"
            "or the backend isn't wired up correctly.")
# Out:
# --- Backend check----------------------------------------
#  stateBackend is working - 1 file(s) in state:
#
#  /notes/todo.txt
# ----------------------------------------
# {'content': '1. Record video \n2. Edit video \n3. Upload video', 'encoding': 'utf-8', 'created_at': '2026-09-02T07:10:35.302331+00:00', 'modified_at': '2026-09-02T07:10:35.302331+00:00'}

# %%
# 4. Prove persistance within the same thread : feed the returned state back in and ask it to read the file

followup = agent2.invoke({
    # carry forward prior messages + the files state
    "messages": result["messages"] + [{
        "role": "user",
        "content": "Read /notes/todo.txt back to me."
    }],
    "files": result.get("files", {})
})

print("\n ------------------Read-book (same thread)--------------------")
print(followup["messages"][-1].content)
# Out:
#  ------------------Read-book (same thread)--------------------
# Here is the content of `/notes/todo.txt`:
#
# ```
# 1. Record video
# 2. Edit video
# 3. Upload video
# ```

# %% [markdown]
# ### FileSystemBackend(Local Disk)

# %%
# Create the agent with a real-disk backend
# root_dir = "." -> files land relative to your current working directory
# virtual_mode = True -> agent uses virtual paths like /notes/todo.txt,
#                            mapped onto root_dir
from deepagents.backends import FilesystemBackend
ROOT = "."

agent = create_deep_agent(model="mistral-small-latest", backend=FilesystemBackend(root_dir=ROOT, virtual_mode=True))
print(f"Agent created with FilesystemBackend(root_dir={ROOT!r}).")
print("Files written by the agent will appear on your ACTUAL disk.")
# Out:
# Agent created with FilesystemBackend(root_dir='.').
# Files written by the agent will appear on your ACTUAL disk.

# %%
result = agent.invoke({
    "messages":[{
        "role": "user",
        "content": (
            "Create a file at /notes/todo.txt with exactly this content: \n"
            "1. Record video \n 2. Edit video \n 3. Upload video\n"
            "Then tell me you have done it."
        )
    }]
})

print("\n --- Agent reply---------------------------")
print(result["messages"][-1].content)
# Out:
#  --- Agent reply---------------------------
# I have created the file `/notes/todo.txt` with the content:
# ```
# 1. Record video
# 2. Edit video
# 3. Upload video
# ```

# %%
# Check the backend is working - look on the REAL disk
from pathlib import Path
print("\n ----Backend check (real filesystem)---------------------")
disk_path = Path(ROOT) / "notes" / "todo.txt"

if disk_path.exists():
    print(f"FileSystemBackend is working - file exists on disk:")
    print(f"{disk_path.resolve()} \n {'-'*40}")
    print(disk_path.read_text())
else:
    print(f"Expected file not found at {disk_path.resolve()}")
    print("The agent may not have called the write tool, or the path mapping differs. ")
# Out:
#  ----Backend check (real filesystem)---------------------
# FileSystemBackend is working - file exists on disk:
# A:\langchainupdated\deepagent\notes\todo.txt
#  ----------------------------------------
# 1. Record video
# 2. Edit video
# 3. Upload video

# %%
fresh_agents =create_deep_agent(
    model="mistral-small-latest",
    backend=FilesystemBackend(root_dir=ROOT, virtual_mode=True),
)

followup1 = fresh_agents.invoke({
    "messages" : [{
        "role": "user",
        "content": "Read /notes/todo.txt back to me verbatim."
    }]
})

print("\n --------------READ-BACK WITH A FRESH AGENT (PROVES DISK PERSISTENCE)----------------")
print(followup1["messages"][-1].content)
# Out:
#  --------------READ-BACK WITH A FRESH AGENT (PROVES DISK PERSISTENCE)----------------
# Here is the content of `/notes/todo.txt` verbatim:
#
# ```
# 1. Record video
# 2. Edit video
# 3. Upload video
# ```

# %% [markdown]
# ### Deep Agent — StoreBackend verification

# %% [markdown]
# Creates a deep agent backed by a LangGraph store, invokes it to write a file on one thread, then proves the backend works by reading that file back on a DIFFERENT thread — something StateBackend cannot do. """

# %%
from langgraph.store.memory import InMemoryStore
from deepagents.backends import StoreBackend
store = InMemoryStore()

agent = create_deep_agent(
    model="mistral-small-latest",
    backend=StoreBackend(
        # Local dev: static namespace. No deployment runtime needed.
        # In a LangSmith Deployment you'd use the user-identity version.
        namespace=lambda rt: ("demo-user",),
    ),
    store=store,
)

print("Agent created with StoreBackend + static namespace.")
# Out:
# Agent created with StoreBackend + static namespace.

# %%
import os
import uuid
# -----------------------------------------------------------------------------
# 2. THREAD 1 — write a file
# -----------------------------------------------------------------------------
thread_1 = {"configurable": {"thread_id": str(uuid.uuid4())}}

result = agent.invoke(
    {
        "messages": [{
            "role": "user",
            "content": (
                "Create a file at /notes/todo.txt with exactly this content:\n"
                "1. Record video\n2. Edit video\n3. Upload video\n"
                "Then tell me you've done it."
            )
        }]
    },
    config=thread_1,
)

print("\n--- Agent reply (thread 1) --------------------------------------")
print(result["messages"][-1].content)
# Out:
# --- Agent reply (thread 1) --------------------------------------
# I've created the file `/notes/todo.txt` with the content you requested.

# %%
# --- Thread 2: read back on a DIFFERENT thread ---------------------------
thread_2 = {"configurable": {"thread_id": str(uuid.uuid4())}}
followup = agent.invoke(
    {"messages": [{
        "role": "user",
        "content": "Read /notes/todo.txt back to me verbatim."
    }]},
    config=thread_2,
)
print("\n--- Read-back on a different thread ---")
print(followup["messages"][-1].content)
# Out:
# --- Read-back on a different thread ---
# Here is the verbatim content of `/notes/todo.txt`:
#
# ```
# 1. Record video
# 2. Edit video
# 3. Upload video
# ```

# %% [markdown]
# With StoreBackend + InMemoryStore, the file is not saved to disk at all. It lives in RAM. inside the InMemoryStore object, as an entry keyed under the namespace.

# %% [markdown]
# ### Deep Agent Backends — Where Your Files Actually Live

# %% [markdown]
# Every Deep Agent works with a virtual filesystem: its tools read and write files using paths like /notes/todo.txt. But those paths are an abstraction. The backend decides where that data physically lives — and that single choice changes everything about persistence, sharing, and durability.
#
# The agent code stays identical across all three. Only the backend changes.

# %% [markdown]
# 1. StateBackend (default)
# Files live in the agent's LangGraph state — i.e. in RAM, tied to a single thread. They're available during the run via result["files"], and you must manually carry that state forward to keep using them.
#
# Where: in-memory dict, inside one thread's state
# Survives: within a single conversation/thread only
# Gone when: the thread ends or the process exits
# Use it for: ephemeral scratch space, temporary working files

# %% [markdown]
# 2. FilesystemBackend
# Files are written to your real disk, under root_dir. With virtual_mode=True, a virtual path like /notes/todo.txt maps to root_dir/notes/todo.txt. These are genuine files you can open in an editor or cat from a terminal.
#
# Where: your actual filesystem, relative to root_dir
# Survives: across process restarts — it's a real file
# Use it for: when the agent should edit real project files
# Caution: grants the agent real read/write disk access — point it at a scratch directory, not anything important

# %% [markdown]
# 3. StoreBackend
# Files live in a LangGraph store, scoped by a namespace. This is the only backend whose files persist across threads/conversations — write on one thread, read back on another. With InMemoryStore this works within a single process; swap in a persistent store (e.g. Postgres-backed) for true cross-restart durability.
#
# Where: inside the store object, under a namespace key
# Survives: across threads sharing the same store
# Gone when: the process exits (if using InMemoryStore) — use a persistent store to outlive restarts
# Use it for: long-term memory, per-user file spaces

# %% [markdown]
# Quick Comparision
#
# Backend	             |  Lives in	      | Cross-thread? | Survives restart?	    |Real file on disk?
# StateBackend	     |  LangGraph state	  |     No	      |       No	            |       No
# FilesystemBackend	 |  Your disk	      |     Yes	      |       Yes	            |       Yes
# StoreBackend	     |  A LangGraph store |     Yes	      | only w/ persistent store|       No
